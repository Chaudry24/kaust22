# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import models
import tensorflow as tf

# set dark background on the plot
plt.style.use("dark_background")

# set cmap to jet
plt.rcParams["image.cmap"] = 'jet'

# %%
my_m1 = models.model1()
my_m2 = models.model2()
my_m3 = models.model3()
my_m4 = models.model4()
my_m5 = models.model5()
my_m6 = models.model6()
my_m7 = models.model7()
# dh_d1 = tf.keras.models.load_model("./deephyper-dat1/best_model/")
# dh_d2 = tf.keras.models.load_model("./deephyper-dat2/best_model/")
# Out:
# 2022-03-27 11:09:06.691766: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-27 11:09:06.692193: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
tf.keras.utils.plot_model(my_m7)

# %%
# ------------- DATA 1 ------------- #

# open my model 1 and 2 evaluation values
with open("./results/val_m1d1.npy", mode="rb") as file:
    m1d1_e = np.load(file)
    
with open("./results/val_m2d1.npy", mode="rb") as file:
    m2d1_e = np.load(file)
    
# open deephyper evauluation
with open("./deephyper-dat1/best_model_results/val_d1.npy", mode="rb") as file:
    dhd1_e = np.load(file)
    
# plot root mean squared errors [2nd index in the array]
plt.scatter(x=["model 1", "model 2", "deep hyper"], y=[m1d1_e[1], m2d1_e[1], dhd1_e[1]], c=["red", "blue", "green"])

# %%
# ------------- DATA 2 ------------- #

# open my model 1 and 2 evaluation values
with open("./results/val_m1d2.npy", mode="rb") as file:
    m1d2_e = np.load(file)
    
with open("./results/val_m2d2.npy", mode="rb") as file:
    m2d2_e = np.load(file)
    
# open deephyper evauluation
with open("./deephyper-dat2/best_model_results/val_d2.npy", mode="rb") as file:
    dhd2_e = np.load(file)
    
    
# plot root mean squared errors [2nd index in the array]
plt.scatter(x=["model 1", "model 2", "deep hyper"], y=[m1d2_e[1], m2d2_e[1], dhd2_e[1]], c=["red", "blue", "green"])
